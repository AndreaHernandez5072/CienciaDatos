# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreaHernandez5072/CienciaDatos/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("diabetes.csv")
print(df.head())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#Ver los datos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
#Verificar valores nulos
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#Analisis estadistico
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
#Detección de Outliers
fig,axs= plt.subplots(9,1,dpi=95,figsize=(7,17))
i = 0
for col in df.columns:
  axs[i].boxplot(df[col],vert=False)
  axs[i].set_ylabel(col)
  i+=1

plt.show()

# %% [markdown]
# Tratamiento de Outliers:
# 1. Eliminar registros que están afuera del rango aceptable

# %%
def EliminaOutliers(col,dataset,cleandata):

  #identificar cuartil 1 y 3
  q1,q3 = np.percentile(dataset[col],[25,75])
  #calcular el IQR
  iqr = q3-q1
  #calcular limite inferior y superior
  limite_inferior = q1 - (1.5*iqr)
  limite_superior = q3 + (1.5*iqr)
  #Eliminar los Outliers
  cleandata = dataset[(dataset[col]>=limite_inferior)  & (dataset[col]<=limite_superior)]
  return cleandata

# %%
clean_data = df
clean_data = EliminaOutliers("Insulin",df,clean_data)
clean_data = EliminaOutliers("Glucose",clean_data,clean_data)
clean_data = EliminaOutliers("BloodPressure",clean_data,clean_data)
clean_data = EliminaOutliers("SkinThickness",clean_data,clean_data)
clean_data = EliminaOutliers("Pregnancies",clean_data,clean_data)
clean_data = EliminaOutliers("BMI",clean_data,clean_data)
clean_data = EliminaOutliers("DiabetesPedigreeFunction",clean_data,clean_data)
clean_data = EliminaOutliers("Age",clean_data,clean_data)
clean_data = EliminaOutliers("Outcome",clean_data,clean_data)
clean_data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   619.000000  619.000000     619.000000     619.000000  619.000000
# mean      3.770598  117.570275      71.888530      20.634895   65.697900
# std       3.246961   27.920533      11.286739      15.203447   78.587721
# min       0.000000   44.000000      38.000000       0.000000    0.000000
# 25%       1.000000   98.500000      64.000000       0.000000    0.000000
# 50%       3.000000  112.000000      72.000000      23.000000   40.000000
# 75%       6.000000  134.000000      80.000000      32.000000  120.000000
# max      13.000000  194.000000     106.000000      60.000000  318.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  619.000000                619.000000  619.000000  619.000000
# mean    31.878675                  0.425031   32.323102    0.298869
# std      6.312691                  0.245535   10.654730    0.458133
# ...

# %% [markdown]
# Agregando límite superior o inferior a los outliers

# %%
def TratamientoOutliers(col,dataset,cleandata):
  #calcular los cuartiles
  q1,q3=np.percentile(dataset[col],[25,75])
  #Calcular iqr
  iqr=q3-q1
  limite_inferior=q1-(1.5*iqr)
  limite_superior=q3+(1.5*iqr)
  #Similar a un IF
  dataset[col]=np.where(dataset[col]>limite_superior,limite_superior,np.where(dataset[col]<limite_inferior,limite_inferior,dataset[col]))

# %%
clean_data = df
TratamientoOutliers("Insulin",clean_data,clean_data)
TratamientoOutliers("Glucose",clean_data,clean_data)
TratamientoOutliers("BloodPressure",clean_data,clean_data)
TratamientoOutliers("SkinThickness",clean_data,clean_data)
TratamientoOutliers("Pregnancies",clean_data,clean_data)
TratamientoOutliers("BMI",clean_data,clean_data)
TratamientoOutliers("DiabetesPedigreeFunction",clean_data,clean_data)
TratamientoOutliers("Age",clean_data,clean_data)
TratamientoOutliers("Outcome",clean_data,clean_data)
clean_data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.837240  121.136230      70.684896      20.511719   73.652669
# std       3.344157   31.187468      14.197239      15.844744   93.576029
# min       0.000000   37.125000      35.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      13.500000  199.000000     107.000000      80.000000  318.125000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.125065                  0.458914   33.199870    0.348958
# std      7.049584                  0.285596   11.628404    0.476951
# ...

# %%
#Detección de Outliers
fig,axs= plt.subplots(9,1,dpi=95,figsize=(7,17))
i = 0
for col in df.columns:
  axs[i].boxplot(df[col],vert=False)
  axs[i].set_ylabel(col)
  i+=1

plt.show()

# %%
#Pandas trae una función llamada corr (correlación)
#Solo funciona con variables númericas
#No variables categoricas
corr2 = clean_data.corr()

plt.figure(dpi=130)
sns.heatmap(clean_data.corr(),annot=True,fmt='.2f')
plt.show()
